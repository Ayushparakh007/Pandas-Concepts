# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}
df=pd.DataFrame(data)
df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    756     15   John  January      Q1
# 1  2023-01-02       B   West    746     77   Mary  January      Q1
# 2  2023-01-03       C  North    182     98    Bob  January      Q1
# 3  2023-01-04       D  South    150     66  Alice  January      Q1
# 4  2023-01-05       A   East    151     13   John  January      Q1
# 5  2023-01-06       B   West    858     93   Mary  January      Q1
# 6  2023-01-07       C  North    468     37    Bob  January      Q1
# 7  2023-01-08       D  South    464     42  Alice  January      Q1
# 8  2023-01-09       A   East    402     91   John  January      Q1
# 9  2023-01-10       B   West    953     16   Mary  January      Q1
# 10 2023-01-11       C  North    594     51    Bob  January      Q1
# 11 2023-01-12       D  South    692     38  Alice  January      Q1
# 12 2023-01-13       A   East    585     99   John  January      Q1
# 13 2023-01-14       B   West    912     39   Mary  January      Q1
# 14 2023-01-15       C  North    698     50    Bob  January      Q1
# 15 2023-01-16       D  South    604     36  Alice  January      Q1
# 16 2023-01-17       A   East    733     93   John  January      Q1
# 17 2023-01-18       B   West    913     28   Mary  January      Q1
# 18 2023-01-19       C  North    140     61    Bob  January      Q1
# 19 2023-01-20       D  South    245     78  Alice  January      Q1

# %%
#Cross Tabs

# %%
pd.pivot_table(df,values='Sales',index='Region',columns='Product',aggfunc='median')
# Out:
# Product      A      B      C      D
# Region
# East     585.0    NaN    NaN    NaN
# North      NaN    NaN  468.0    NaN
# South      NaN    NaN    NaN  464.0
# West       NaN  912.0    NaN    NaN

# %%
pivot2 = pd.pivot_table(df, values=['Sales', 'Units'], index='Region', columns='Product')
pivot2
# values this must be only numeric value
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     525.4    NaN    NaN    NaN  62.2   NaN   NaN   NaN
# North      NaN    NaN  416.4    NaN   NaN   NaN  59.4   NaN
# South      NaN    NaN    NaN  431.0   NaN   NaN   NaN  52.0
# West       NaN  876.4    NaN    NaN   NaN  50.6   NaN   NaN

# %%
 #cross TABS

# %%
pd.crosstab(df['Region'],df['Product']) #cross tab is used for counting method
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
